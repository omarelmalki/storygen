# %%
import networkx as nx
import pandas as pd
import matplotlib.pyplot as plt

# %%
def draw(graph):
    plt.figure(figsize=(20, 10), dpi=80)
    pos=nx.spring_layout(graph)
    nx.draw_networkx(graph, pos, node_size=5000)
    labels = dict([((fe,se,),e['rel'])
        for fe,se,e in graph.edges(data=True)])
    nx.draw(graph, pos)
    plt.show()

# %%
graphs = pd.read_pickle('../../generated/graph_construction/sample_ROCStories_graphs.pkl')

# %%
graph = graphs['graph_1'][0]

# %%
draw(graph)

# %%
pruned_graph = graphs['pruned_graph_1'][0]

# %%
draw(pruned_graph)
